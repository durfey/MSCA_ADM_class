# %% [markdown]
# # Problem Set 1: Part 3
# ## ISLR Chapter 2 Exercise 10

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Part A

# %%
## read in the data
boston = pd.read_csv("./Boston.csv")
boston.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       black  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
## how many rows and columns?
boston.shape
# Out:
# (506, 14)

# %% [markdown]
# There are 506 rows and 14 columns. They represent the observations (rows) and variables (columns)

# %% [markdown]
# ### Part B

# %%
## create a pairwise scatterplot of some of the variables
## we'll choose to use the first 8 variables
boston7 = boston[['crim','zn','indus','chas','nox','rm','age','ptratio']]
boston7.head()
axes = pd.tools.plotting.scatter_matrix(boston7,alpha=0.2)
plt.tight_layout()

# %% [markdown]
# ### Part C

# %% [markdown]
# From the scatterplots above, the variables 'indus', 'age', and 'ptratio' appear to potentially have an association with 'crim', the per capita crime rate. These relationships appear to be a positive one, with higher 'crim' being more prevalent with higher values of the other predictors.

# %% [markdown]
# ### Part D

# %%
## looking at crime rate
#boston.crim.describe()
plt.hist(boston.crim)
boston[boston.crim>30]
# Out:
#         crim  zn  indus  chas    nox     rm    age     dis  rad  tax  ptratio  \
# 380  88.9762   0   18.1     0  0.671  6.968   91.9  1.4165   24  666     20.2
# 398  38.3518   0   18.1     0  0.693  5.453  100.0  1.4896   24  666     20.2
# 404  41.5292   0   18.1     0  0.693  5.531   85.4  1.6074   24  666     20.2
# 405  67.9208   0   18.1     0  0.693  5.683  100.0  1.4254   24  666     20.2
# 410  51.1358   0   18.1     0  0.597  5.757  100.0  1.4130   24  666     20.2
# 414  45.7461   0   18.1     0  0.693  4.519  100.0  1.6582   24  666     20.2
# 418  73.5341   0   18.1     0  0.679  5.957  100.0  1.8026   24  666     20.2
# 427  37.6619   0   18.1     0  0.679  6.202   78.7  1.8629   24  666     20.2
#
#       black  lstat  medv
# 380  396.90  17.21  10.4
# 398  396.90  30.59   5.0
# 404  329.46  27.38   8.5
# 405  384.97  22.98   5.0
# 410    2.60  10.11  15.0
# 414   88.27  36.98   7.0
# 418   16.45  20.62   8.8
# 427   18.82  14.52  10.9

# %% [markdown]
# We can see that there are 8 Boston suburbs that have a per capita crime rate of over 30, which is very much higher than all other suburbs. We should probably steer clear of those burbs if visiting Boston.

# %%
## look at tax rate
plt.hist(boston.tax)
boston[boston.tax>666]
#boston.tax.describe()
# Out:
#         crim  zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 488  0.15086   0  27.74     0  0.609  5.454  92.7  1.8209    4  711     20.1
# 489  0.18337   0  27.74     0  0.609  5.414  98.3  1.7554    4  711     20.1
# 490  0.20746   0  27.74     0  0.609  5.093  98.0  1.8226    4  711     20.1
# 491  0.10574   0  27.74     0  0.609  5.983  98.8  1.8681    4  711     20.1
# 492  0.11132   0  27.74     0  0.609  5.983  83.5  2.1099    4  711     20.1
#
#       black  lstat  medv
# 488  395.09  18.06  15.2
# 489  344.05  23.97   7.0
# 490  318.43  29.68   8.1
# 491  390.11  18.07  13.6
# 492  396.90  13.35  20.1

# %% [markdown]
# Here, we see 5 suburbs that have high tax. All have a value of 711.

# %%
## look at pupil-teacher ratio
plt.hist(boston.ptratio)
boston.ptratio.describe()
boston[boston.ptratio>21]
# Out:
#         crim  zn  indus  chas    nox     rm    age      dis  rad  tax  \
# 54   0.01360  75   4.00     0  0.410  5.888   47.6   7.3197    3  469
# 127  0.25915   0  21.89     0  0.624  5.693   96.0   1.7883    4  437
# 128  0.32543   0  21.89     0  0.624  6.431   98.8   1.8125    4  437
# 129  0.88125   0  21.89     0  0.624  5.637   94.7   1.9799    4  437
# 130  0.34006   0  21.89     0  0.624  6.458   98.9   2.1185    4  437
# 131  1.19294   0  21.89     0  0.624  6.326   97.7   2.2710    4  437
# 132  0.59005   0  21.89     0  0.624  6.372   97.9   2.3274    4  437
# 133  0.32982   0  21.89     0  0.624  5.822   95.4   2.4699    4  437
# 134  0.97617   0  21.89     0  0.624  5.757   98.4   2.3460    4  437
# 135  0.55778   0  21.89     0  0.624  6.335   98.2   2.1107    4  437
# 136  0.32264   0  21.89     0  0.624  5.942   93.5   1.9669    4  437
# 137  0.35233   0  21.89     0  0.624  6.454   98.4   1.8498    4  437
# ...

# %% [markdown]
# There are 18 suburbs that have a pupil-teacher ratio above 21.

# %% [markdown]
# ### Part E

# %%
## how many bound the Charles river?
boston[boston.chas==1].shape
# Out:
# (35, 14)

# %% [markdown]
# 35 Suburbs bound the Charles river.

# %% [markdown]
# ### Part F

# %%
boston.ptratio.median()
# Out:
# 19.05

# %% [markdown]
# The median of pupil-teacher ratios is 19.05.

# %% [markdown]
# ### Part G

# %%
boston[boston.age==boston.age.min()]
# Out:
#        crim  zn  indus  chas    nox    rm  age     dis  rad  tax  ptratio  \
# 41  0.12744   0   6.91     0  0.448  6.77  2.9  5.7209    3  233     17.9
#
#      black  lstat  medv
# 41  385.41   4.84  26.6

# %% [markdown]
# Suburb number 41 has the lowest owner-occupied homes (age variable)

# %%
## compare with ranges of entire dataset
boston.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       black  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# ### Part H

# %%
## how many suburbs average more than seven rooms per dwelling?
print boston[boston.rm > 7].shape

## how many suburbs average more than eight rooms per dwelling?
print boston[boston.rm > 8].shape
# Out:
# (64, 14)
# (13, 14)

# %%
There are 64 suburbs that average more than seven rooms per dwelling, but only 13 suburbs that average more than 8 rooms.
